# %% [markdown]
# # Exploring the data
# ---
# *With pandas!*

# %%
from parse_json import *

# %% [markdown]
# ## Foursquare:

# %%
json_obj = json_from_file("Foursquare_restaurants_p1.json")
foursquare = parse_object_to_df(
    json_obj, legend_discrepencies=FOURSQUARE_LEGEND_DISCREPANCIES
)
foursquare["RatingCount"] = post_process_series(foursquare["RatingCount"])
foursquare.tail()
# Out:
# 50
#                         Name  Price  \
# 45    BeaverTails Canada Inc    1.0
# 46     Ahora Mexican Cuisine    2.0
# 47               Chez Lucien    2.0
# 48                 El Camino    1.0
# 49  The Keg Steakhouse + Bar    3.0
#
#                                                  Type  Rating  RatingCount  \
# 45  [desserts, cheese, lunch, chocolate, pastries,...     8.6        221.0
# 46  [chicken, Mexican food, lunch, cocktails, taco...     7.8        135.0
# 47  [good service, beer, burgers, fruit, cheese, s...     8.8        257.0
# 48  [cocktails, tacos, chips and salsa, ox tongue,...     8.8         31.0
# 49  [chicken, cocktails, steak, shrimp, outdoor se...     8.2         98.0
#
#         Source
# 45  Foursquare
# 46  Foursquare
# 47  Foursquare
# 48  Foursquare
# 49  Foursquare

# %% [markdown]
# ## Yelp:

# %%
json_obj = json_from_file("Yelp_restaurants.json")
yelp = parse_object_to_df(
    json_obj, "businesses", legend_discrepencies=YELP_LEGEND_DISCREPANCIES
)
yelp.tail()
# Out:
# 50
#                                   Name Price  \
# 45                  Fiazza Fresh Fired    $$
# 46                      Benny's Bistro    $$
# 47  La Bottega Nicastro Fine Food Shop    $$
# 48               Ahora Mexican Cuisine    $$
# 49                         BeaverTails     $
#
#                                                  Type  Rating  RatingCount  \
# 45             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0          136
# 46         [{'alias': 'bistros', 'title': 'Bistros'}]     4.5          113
# 47  [{'alias': 'delis', 'title': 'Delis'}, {'alias...     4.5          153
# 48  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.5          179
# 49  [{'alias': 'desserts', 'title': 'Desserts'}, {...     4.5          246
#
#    Source
# 45   Yelp
# 46   Yelp
# 47   Yelp
# 48   Yelp
# 49   Yelp

# %% [markdown]
# ## Google:

# %%
# Load in the seperate files.
google = pd.DataFrame()
for integer in range(1, 4):
    file_name = f"Google_restaurants_p{integer}.json"
    json_obj = json_from_file(file_name)
    temp = parse_object_to_df(
        json_obj, legend_discrepencies=GOOGLE_LEGEND_DISCREPANCIES
    )
    google = google.append(temp, True)
google.tail()
# Out:
# 20
# 20
# 20
#                          Name  Price  \
# 55      Lone Star Texas Grill    2.0
# 56              The King Eddy    2.0
# 57                       iPho    NaN
# 58  Blue Cactus Bar and Grill    2.0
# 59              Le Casablanca    NaN
#
#                                                  Type  Rating  RatingCount  \
# 55  [restaurant, food, point_of_interest, establis...     4.1         1789
# 56  [meal_delivery, meal_takeaway, bar, restaurant...     4.2         2353
# 57  [restaurant, food, point_of_interest, establis...     3.7          366
# 58  [restaurant, food, point_of_interest, establis...     3.9         1555
# 59  [meal_delivery, meal_takeaway, restaurant, foo...     4.4          211
#
#     Source
# 55  Google
# 56  Google
# 57  Google
# 58  Google
# 59  Google

# %%
# Keep a random 50 rows from Google to equal the sample size. Random state for reproducibility.
google = google.sample(50, axis="index", random_state=411)
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 54 to 46
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         50 non-null     object
#  1   Price        38 non-null     float64
#  2   Type         50 non-null     object
#  3   Rating       50 non-null     float64
#  4   RatingCount  50 non-null     int64
#  5   Source       50 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.7+ KB

# %% [markdown]
# ## Comparisons

# %%
print(
    "Total ratings:",
    f'Foursquare: {int(foursquare["RatingCount"].sum())}',
    f'Yelp: {yelp["RatingCount"].sum()}',
    f'Google: {google["RatingCount"].sum()}',
    sep="\n",
)
# Out:
# Total ratings:
# Foursquare: 3808
# Yelp: 3759
# Google: 52672

# %%
# top 20 from each:
foursquare[["Name", "Rating", "Price"]].sort_values(by="Rating", ascending=False).head(
    20
)
# Out:
#                                    Name  Rating  Price
# 48                            El Camino     8.8    1.0
# 47                          Chez Lucien     8.8    2.0
# 45               BeaverTails Canada Inc     8.6    1.0
# 38                     Play Food & Wine     8.5    3.0
# 40                             E18hteen     8.4    4.0
# 44                   Fiazza Fresh Fired     8.3    1.0
# 49             The Keg Steakhouse + Bar     8.2    3.0
# 35              Bridgehead Coffee House     8.1    2.0
# 34  Sidedoor Contemporary Kitchen & Bar     8.0    3.0
# 39                          Zak's Diner     8.0    2.0
# 33                           Bridgehead     7.9    1.0
# 37                    Chateau Lafayette     7.9    2.0
# 31                               Social     7.9    3.0
# 42                    Bite Burger House     7.9    2.0
# 43             Burgers n' Fries Forever     7.9    3.0
# 23                     The Albion Rooms     7.8    3.0
# 46                Ahora Mexican Cuisine     7.8    2.0
# 36                 Lookout Bar & Bistro     7.8    3.0
# 19              Metropolitain Brasserie     7.6    2.0
# 28                       Piccolo Grande     7.6    1.0

# %%
# top 10 from each:
yelp[["Name", "Rating", "Price"]].sort_values(by="Rating", ascending=False).head(20)
# Out:
#                                     Name  Rating Price
# 49                           BeaverTails     4.5     $
# 42                       Corazón De Maíz     4.5     $
# 28                    Level One Game Pub     4.5    $$
# 34                Shanghai Wonton Noodle     4.5     $
# 35  Food Mood: Korean & Japanese Kitchen     4.5    $$
# 16                             Pili Pili     4.5    $$
# 13                    Sur Lie Restaurant     4.5  $$$$
# 24                               Oz Kafe     4.5   $$$
# 23                            La Catrina     4.5   $$$
# 8         Gyubee Japanese Grill - Ottawa     4.5   $$$
# 7                   Courtyard Restaurant     4.5   $$$
# 44                     Bite Burger House     4.5    $$
# 46                        Benny's Bistro     4.5    $$
# 47    La Bottega Nicastro Fine Food Shop     4.5    $$
# 41            The Keg Steakhouse And Bar     4.0   $$$
# 40                        Kochin Kitchen     4.0    $$
# 43                    Play Food And Wine     4.0   $$$
# 37   Sidedoor Contemporary Kitchen & Bar     4.0   $$$
# 36                           Luxe Bistro     4.0   $$$
# 45                    Fiazza Fresh Fired     4.0    $$

# %%
google[["Name", "Rating", "Price"]].sort_values(by="Rating", ascending=False).head(20)
# Out:
#                                                  Name  Rating  Price
# 1                  La Bottega Nicastro, ByWard Market     4.7    NaN
# 48                          BeaverTails Byward Market     4.6    1.0
# 18                                        Chez Lucien     4.6    2.0
# 25                            il Perugino Caffè & Bar     4.6    2.0
# 46                                       Fairouz Cafe     4.5    3.0
# 38                        Fatboys Southern Smokehouse     4.5    2.0
# 39                     Oz Kafe, ByWard Market, Ottawa     4.5    NaN
# 53                                     Benny's Bistro     4.5    2.0
# 9                                 Restaurant e18hteen     4.5    NaN
# 19                                      ByWard Market     4.5    NaN
# 29                 The Bistro – Eat. Drink. Connect.®     4.5    NaN
# 16           The Keg Steakhouse + Bar - Ottawa Market     4.5    3.0
# 32                               Courtyard Restaurant     4.4    3.0
# 59                                      Le Casablanca     4.4    NaN
# 43                                       Island Flava     4.4    1.0
# 37                           Ahora Mexican Restaurant     4.4    1.0
# 10                                        Sushi Fresh     4.4    2.0
# 23                         s o m e w h e r e dine bar     4.4    3.0
# 6   The Chateau Lafayette House (The Laff), ByWard...     4.4    1.0
# 36               Planet Coffee, ByWard Market, Ottawa     4.3    2.0

# %% [markdown]
# Beavertails consistently ranks among the highest for all platforms!
